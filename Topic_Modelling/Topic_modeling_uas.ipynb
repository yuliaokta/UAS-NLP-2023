# %% [markdown]
# ## **Topic modeling pada dataset All Brands kosmetik dari Sociolla.com**

# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 59.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# ...
# WARNING: bertopic 0.16.0 does not provide the extra 'visualization'
# ...

# %%
#import packages

import pandas as pd
import numpy as np
from bertopic import BERTopic
import string

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/UasNLP/TopicModelling/all_brands_kosmetik.csv')
# Out:
# Mounted at /content/drive

# %%
df.head(10)
# Out:
#   brand_name                  product_name  product_id  beauty_point_earned  \
# 0    796_3ce       MULTI EYE COLOR PALETTE       97802                  130
# 1    796_3ce               VELVET LIP TINT       97810                   50
# 2    796_3ce                     LIP COLOR       97822                   60
# 3    796_3ce  MINI MULTI EYE COLOR PALETTE       97833                   80
# 4    796_3ce                    FACE BLUSH       97801                   60
# 5    796_3ce               BLUR WATER TINT       97817                   50
# 6    796_3ce                CLOUD LIP TINT       97818                   50
# 7    796_3ce    NEW TAKE EYESHADOW PALETTE       98428                  170
# 8    796_3ce    SUPER SLIM EYE BROW PENCIL       98369                   40
# 9    796_3ce         VELVET FIT FOUNDATION       98368                  110
#
#                price_range price_by_combinations  \
# 0  Rp 555.000 - Rp 687.000                   NaN
# ...

# %%
def clean_text(text):
  delete_dict ={sp_character: '' for sp_character in string.punctuation}
  delete_dict[' '] = ' '
  table = str.maketrans(delete_dict)
  text1 = text.translate(table)
  textArr = text1.split()
  text2 = ' '.join([w for w in textArr if (not w.isdigit() and (not w.isdigit() and len(w)>3))])

  return text2.lower()

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df.dropna(axis = 0, how = 'any', inplace=True)

# %%
df.head()
# Out:
#    brand_name                        product_name  product_id  \
# 19    796_3ce                     TATTOO LIP TINT      102642
# 27   751_abib       Quick Sunstick Protection Bar       91207
# 31   751_abib  Heartleaf Sun Essence Calming Drop       91895
# 32   751_abib       Gummy Sheet Mask Milk Sticker       91194
# 33   751_abib   Jericho Rose Creme Nutrition Tube       98624
#
#     beauty_point_earned price_range  \
# 19                   40  Rp 229.000
# 27                   80  Rp 400.000
# 31                   70  Rp 390.000
# 32                   10   Rp 56.000
# 33                   90  Rp 490.000
#
#                                 price_by_combinations  \
# 19  "#CANDY JELLY": 229000; "#LUZTIC": 229000; "#Y...
# 27                                      "22g": 400000
# 31                                     "50ml": 390000
# 32                                      "30ml": 56000
# 33                                    "75 ml": 490000
#
# ...

# %%
df['average_rating_by_types'] = df['average_rating_by_types'].apply(clean_text)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
def remove_stopwords(text):
  textArr = text.split(' ')
  rem_text = " ".join([i for i in textArr if i not in stop_words])
  return rem_text

df['average_rating_by_types'] = df['average_rating_by_types'].apply(remove_stopwords)

# %%
df['average_rating_by_types'].head()
# Out:
# 19    starlongwear starpackaging starpigmentation st...
# 27    stareffectiveness starpackaging startexture st...
# 31    stareffectiveness starpackaging startexture st...
# 32    stareffectiveness starpackaging startexture st...
# 33    stareffectiveness starpackaging startexture st...
# Name: average_rating_by_types, dtype: object

# %%
model = BERTopic(verbose=True)

docs = df.average_rating_by_types.to_list()
topics, probabilities = model.fit_transform(docs)
# Out:
# 2024-01-23 13:05:16,111 - BERTopic - Embedding - Transforming documents to embeddings.
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...

# %%
model.get_topic_freq().head(21)
# Out:
#    Topic  Count
# 5      0   1048
# 1      1    588
# 0      2    555
# 8      3    291
# 2      4     95
# 3      5     57
# 7      6     49
# 4      7     42
# 6     -1     13

# %%
model.get_topic(0)
# Out:
# [('stareffectiveness', 0.12258045617496532),
#  ('startexture', 0.10145517054152886),
#  ('starpackaging', 0.0984712630668615),
#  ('starvalueformoney', 0.09647150199074371),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05)]

# %%
model.get_topic(1)
# Out:
# [('stareffectiveness', 0.12266826452466087),
#  ('startexture', 0.10143096844931954),
#  ('starpackaging', 0.09844777278464137),
#  ('starvalueformoney', 0.09644848875076502),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05),
#  ('', 1e-05)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = BERTopic(nr_topics=40)

# %%
topics, probabilities = model.fit_transform(docs)

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
